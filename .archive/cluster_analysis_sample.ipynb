# %%
import os
import re
import nltk
import mpld3
import joblib
import string
import codecs
# import sklearn.externals
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup
from itertools import chain
from functools import partial

from nltk.tag import pos_tag
from nltk.stem.snowball import SnowballStemmer

from sklearn.manifold import MDS
from sklearn.cluster import KMeans
from sklearn import feature_extraction
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

from scipy.cluster.hierarchy import ward
from scipy.cluster.hierarchy import dendrogram

from gensim import corpora
from gensim import models
from gensim import similarities

# %%
# %matplotlib inline

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %%
random_state = 42

# %% [markdown]
# # Data

# %% [markdown]
# ## load

# %%
#import three lists: titles, links and wikipedia synopses
titles = open('title_list.txt').read().split('\n')
links = open('link_list_imdb.txt').read().split('\n')
synopses_wiki = open('synopses_list_wiki.txt').read().split('\n BREAKS HERE')
genres = open('genres_list.txt').read().split('\n')
synopses_imdb = open('synopses_list_imdb.txt').read().split('\n BREAKS HERE')

# %% [markdown]
# ## etl

# %% [raw]
# n = 100
#
# titles = titles[:n]
# links = links[:n]
# synopses_wiki = synopses_wiki[:n]
# genres = genres[:n]
# synopses_imdb = synopses_imdb[:n]

# %%
synopses_clean_wiki = []
for text in synopses_wiki:
    text = BeautifulSoup(text, 'html.parser').getText()
    #strips html formatting and converts to unicode
    synopses_clean_wiki.append(text)

synopses_wiki = synopses_clean_wiki

# %%
synopses_clean_imdb = []

for text in synopses_imdb:
    text = BeautifulSoup(text, 'html.parser').getText()
    #strips html formatting and converts to unicode
    synopses_clean_imdb.append(text)

synopses_imdb = synopses_clean_imdb

# %%
synopses = []

for i in range(len(synopses_wiki)):
    item = synopses_wiki[i] + synopses_imdb[i]
    synopses.append(item)

# %%
ranks = range(len(titles))

# %%
print(str(len(titles)) + ' titles')
print(str(len(links)) + ' links')
print(str(len(synopses_wiki)) + ' synopses')
print(str(len(genres)) + ' genres')
# Out:
# 101 titles
# 101 links
# 101 synopses
# 101 genres

# %% [markdown]
# ## table

# %% [markdown]
# films, 电影
#
# | 字段名| 字段说明 |
# | :-- | :-- |
# | title | 名称 |
# | rank | 排名 |
# | synopses | 概要 |
# | genres | 流派 |

# %%
films = { 'title': titles, 'rank': ranks, 'synopsis': synopses, 'genre': genres}
df_films = pd.DataFrame(films)

# %%
df_films.shape
# Out:
# (101, 4)

# %%
df_films.head(1)
# Out:
#            title  rank                                           synopsis  \
# 0  The Godfather     0   Plot  [edit]  [  [  edit  edit  ]  ]  \n  On ...
#
#                     genre
# 0  [u' Crime', u' Drama']

# %% [markdown]
# # Preprocess

# %% [markdown]
# ## tokenizing

# %%
def tokenize(stemmer, text):
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = [token for token in tokens if re.search('[a-zA-Z]', token)]
    stemmed = [stemmer.stem(t) for t in filtered_tokens]
    return filtered_tokens, stemmed

# %%
nltk.download('punkt')
stemmer = SnowballStemmer("english")
# Out:
# [nltk_data] Downloading package punkt to /home/wangyh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
totalvocab_tokenized, totalvocab_stemmed = zip(*map(partial(tokenize, stemmer), synopses))
totalvocab_tokenized = chain.from_iterable(totalvocab_tokenized)
totalvocab_stemmed = chain.from_iterable(totalvocab_stemmed)

# %%
df_tokens = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)

# %%
df_tokens.head(1)
# Out:
#      words
# plot  Plot

# %% [markdown]
# # Embedding

# %% [markdown]
# ## n-dim

# %%
def tokenizer(stemmer, text):
    _, stemmed = tokenize(stemmer, text)
    return stemmed

# %%
tfidf_vectorizer = TfidfVectorizer(
    max_df=0.8, 
    max_features=200000,
    min_df=0.2, 
    stop_words='english',
    use_idf=True, 
    tokenizer=partial(tokenizer, stemmer), 
    ngram_range=(1,3)
)

# %%
# %time tfidf_matrix = tfidf_vectorizer.fit_transform(synopses)
# Out:
# /home/wangyh/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'afterward', 'alon', 'alreadi', 'alway', 'ani', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becaus', 'becom', 'befor', 'besid', 'cri', 'describ', 'dure', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'forti', 'henc', 'hereaft', 'herebi', 'howev', 'hundr', 'inde', 'mani', 'meanwhil', 'moreov', 'nobodi', 'noon', 'noth', 'nowher', 'onc', 'onli', 'otherwis', 'ourselv', 'perhap', 'pleas', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'themselv', 'thenc', 'thereaft', 'therebi', 'therefor', 'togeth', 'twelv', 'twenti', 'veri', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev', 'whi', 'yourselv'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# CPU times: user 6.78 s, sys: 44 ms, total: 6.83 s
# Wall time: 6.83 s

# %%
print(tfidf_matrix.shape)
# Out:
# (101, 532)

# %% [markdown]
# ## n-dim distance

# %%
dist = 1 - cosine_similarity(tfidf_matrix)

# %%
dist.shape
# Out:
# (101, 101)

# %% [markdown]
# ## 2-dim

# %%
MDS()

# two components as we're plotting points in a two-dimensional plane
# "precomputed" because we provide a distance matrix
# we will also specify `random_state` so the plot is reproducible.
mds = MDS(n_components=2, dissimilarity="precomputed", random_state=random_state)

# %%
# shape = (n_samples, n_components)
pos = mds.fit_transform(dist)
pos.shape
# Out:
# (101, 2)

# %%
xs, ys = pos[:, 0], pos[:, 1]

# %% [markdown]
# # Clustering

# %% [markdown]
# ## k-means

# %%
num_clusters = 5
km = KMeans(n_clusters=num_clusters, random_state=random_state)

# %%
# TODO: may be need normalize/scaling before clustering

# %%
# %time km.fit(tfidf_matrix)
# Out:
# CPU times: user 316 ms, sys: 8 ms, total: 324 ms
# Wall time: 81.1 ms
# KMeans(n_clusters=5, random_state=42)

# %%
# joblib.dump(km,  'doc_cluster.pkl')
# km = joblib.load('doc_cluster.pkl')
# clusters = km.labels_.tolist()

# %% [markdown]
# ## linkage ward

# %% [raw]
# # TODO:
# #
# # each level cluster num, keywords
# # evaluate which level give best clustering

# %% [raw]
# linkage_matrix = ward(dist) #define the linkage_matrix using ward clustering pre-computed distances
# linkage_matrix.shape

# %% [markdown]
# ## latent dirichlet allocation

# %%
# TODO:

#strip any proper names from a text...unfortunately right now this is yanking the first word from a sentence too.
def strip_proppers(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent) if word.islower()]
    return "".join([" "+i if not i.startswith("'") and i not in string.punctuation else i for i in tokens]).strip()

# %%
nltk.download("stopwords")
stopwords = nltk.corpus.stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /home/wangyh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#remove proper names
preprocess = [strip_proppers(doc) for doc in synopses]
len(preprocess)
# Out:
# 101

# %%
# %time tokenized_text = [tokenize(stemmer, text)[1] for text in preprocess]
# Out:
# CPU times: user 3.31 s, sys: 16 ms, total: 3.33 s
# Wall time: 3.33 s

# %%
# %time texts = [[word for word in text if word not in stopwords] for text in tokenized_text]
print(len(texts[0]))
# Out:
# CPU times: user 436 ms, sys: 0 ns, total: 436 ms
# Wall time: 435 ms
# 1839

# %%
dictionary = corpora.Dictionary(texts)
dictionary.filter_extremes(no_below=1, no_above=0.8)

# %%
corpus = [dictionary.doc2bow(text) for text in texts]
len(corpus)
# Out:
# 101

# %%
# %time lda = models.LdaModel(corpus, \
                            num_topics=5, \
                            id2word=dictionary, \
                            update_every=5, \
                            chunksize=10000, \
                            passes=100, \
                            random_state=random_state)

print(lda[corpus[0]])
# Out:
# CPU times: user 2min 48s, sys: 3.94 s, total: 2min 52s
# Wall time: 43.2 s
# [(0, 0.9869438), (1, 0.012684074)]

# %%
topics = lda.print_topics(5, num_words=20)

topics_matrix = lda.show_topics(formatted=False, num_words=20)
topics_matrix[:1]
# Out:
# [(0,
#   [('famili', 0.006870739),
#    ('love', 0.0062198904),
#    ('father', 0.0060311556),
#    ('meet', 0.0049668313),
#    ('ask', 0.004406741),
#    ('home', 0.0042756144),
#    ('friend', 0.004109717),
#    ('polic', 0.004085137),
#    ('marri', 0.0040527303),
#    ('becom', 0.003906237),
#    ('want', 0.0037261767),
#    ('kill', 0.0036896744),
#    ('later', 0.0036892067),
#    ('fight', 0.0036726026),
#    ('arriv', 0.00365863),
#    ('brother', 0.0036567436),
#    ('first', 0.0035230615),
#    ('day', 0.00346496),
#    ('life', 0.0034357065),
#    ('work', 0.0032850078)])]

# %% [markdown]
# # Report

# %%
def termid_to_token(termid, terms, df_tokens):
    term = terms[termid]
    term = term.split(' ')
    token = df_tokens.loc[term].values.tolist()[0][0]
    # token = token.encode('utf-8', errors='ignore')
    return token

# %%
def cluster_topics(i, k, cluster_centers_, terms, df_tokens):
    order_centroids = cluster_centers_.argsort()[:, ::-1]
    
    # return [[termid_to_token(ind, terms, df_tokens) for ind in order_centroids[i, :k]] 
    #     for i in range(cluster_centers_.shape[0])]
    
    return [termid_to_token(ind, terms, df_tokens) for ind in order_centroids[i, :k]]

# %%
def get_cluster_names(k, cluster_centers_, terms, df_tokens):
    return [','.join(cluster_topics(i, k, cluster_centers_, terms, df_tokens)) for i in range(len(cluster_centers_))]

# %%
def cluster_info(i, df_films, info):
    return df_films[df_films['cluster']==i][info].values.tolist()

# %%
# def pprint(num_clusters, order_centroids, terms, df_tokens, df_films):

def pprint(num_clusters, cluster_centers_, terms, df_tokens, df_films, k):

    print("Top terms per cluster:")
    print()

    for i in range(num_clusters):

        """ term import -> term vector
        """

        print("Cluster %d words:" % i, end='')

        # for ind in order_centroids[i, :6]:
        #    term = terms[ind]
        #    term = term.split(' ')
        #    token = df_tokens.loc[term].values.tolist()[0][0]
        #    token = token.encode('utf-8', errors='ignore')
        #   print(token, end=',')
        
        for token in cluster_topics(i, k, cluster_centers_, terms, df_tokens):
            print(token, end=',')

        print()
        print()

        """ cluster id -> title
        """

        print("Cluster %d titles:" % i, end='')

        # for title in df_films[df_films['cluster']==i]['title'].values.tolist():
        #     print(' %s,' % title, end='')
        
        for title in cluster_info(i, df_films, 'title'):
            print(' %s,' % title, end='')

        print()
        print()

# %%
def report_pprint(df_films, clusters, terms, cluster_centers_, num_clusters, df_tokens, k):
    """
    Parameter
    --------
    df_films : pd.DataFrame, shape=(n_samples, n_dim)
        title, rank, synopsis, genre
        
    clusters : list
    
    terms : vector feature name
    
    cluster_centers_ : np.array, shape=(n_clusters, n_terms)
    
    num_clusters : int
    
    df_tokens : pd.DataFrame, shape=(n_tokens), index=stemmed
        tokens repeat
    """
    
    # add cluster info
    df_films['cluster'] = clusters
    df_films['cluster'].value_counts()
    df_films[['rank', 'cluster']].groupby('cluster').mean()
    
    # top tokens
    # terms = tfidf_vectorizer.get_feature_names()
    print(len(terms))
    print(cluster_centers_.shape)
    # order_centroids = cluster_centers_.argsort()[:, ::-1]
    
    # pprint(num_clusters, order_centroids, terms, df_tokens, df_films)
    pprint(num_clusters, cluster_centers_, terms, df_tokens, df_films, k)

# %%
def visualizing(groups, cluster_names, cluster_colors, df_cluster):
    
    fig, ax = plt.subplots(figsize=(17, 9)) # set size
    ax.margins(0.05) # adds 5% padding to the autoscaling


    for name, group in groups:
        ax.plot(group.x, group.y, marker='o', linestyle='', ms=12, label=cluster_names[name], color=cluster_colors[name], mec='none')

        ax.set_aspect('auto')

        ax.tick_params(\
            axis= 'x',          # changes apply to the x-axis
            which='both',   # both major and minor ticks are affected
            bottom='off',    # ticks along the bottom edge are off
            top='off',         # ticks along the top edge are off
            labelbottom='off')

        ax.tick_params(\
            axis= 'y',
            which='both',
            left='off',
            top='off',
            labelleft='off')

    ax.legend(numpoints=1)  #show legend with only 1 point


    #add label in x,y position with the label as the film title
    for i in range(len(df_cluster)):
        ax.text(df_cluster.iloc[i]['x'], df_cluster.iloc[i]['y'], df_cluster.iloc[i]['title'], size=8)  


    plt.show()
    #plt.savefig('clusters_small_noaxes.png', dpi=200)

# %%
def report_visualizing(xs, ys, clusters, titles, cluster_colors, cluster_names):

    df_cluster = pd.DataFrame(dict(x=xs, y=ys, label=clusters, title=titles))
    print(df_cluster.shape)
    print(df_cluster.head(1))

    # cluster_colors = {0: '#1b9e77', 1: '#d95f02', 2: '#7570b3', 3: '#e7298a', 4: '#66a61e'}

    # cluster_names = {
    #     0: 'Family, home, war', 
    #     1: 'Police, killed, murders', 
    #     2: 'Father, New York, brothers', 
    #     3: 'Dance, singing, love', 
    #     4: 'Killed, soldiers, captain'}

    groups = df_cluster.groupby('label')
    
    visualizing(groups, cluster_names, cluster_colors, df_cluster)

# %%
def report(df_films, clusters, terms, cluster_centers_, num_clusters, df_tokens, xs, ys, titles, cluster_colors, cluster_names, k):
    report_pprint(df_films, clusters, terms, cluster_centers_, num_clusters, df_tokens, k)
    report_visualizing(xs, ys, clusters, titles, cluster_colors, cluster_names)

# %%
# cluster_colors = {0: '#1b9e77', 1: '#d95f02', 2: '#7570b3', 3: '#e7298a', 4: '#66a61e'}
cluster_colors = {0: 'blue', 1: 'orange', 2: 'green', 3: 'red', 4: 'purple'}

# cluster_names = {
#     0: 'Family, home, war', 
#     1: 'Police, killed, murders', 
#     2: 'Father, New York, brothers', 
#     3: 'Dance, singing, love', 
#     4: 'Killed, soldiers, captain'}

# %%
k = 3

# %% [markdown]
# ## k-means

# %%
clusters = km.labels_.tolist()
cluster_centers_ = km.cluster_centers_
terms = tfidf_vectorizer.get_feature_names()
cluster_names = get_cluster_names(k, cluster_centers_, terms, df_tokens)
cluster_names
# Out:
# ['family,father,home',
#  'New,New,York',
#  'killed,soldiers,Army',
#  'Police,car,asks',
#  'George,marries,woman']

# %%
report(df_films, clusters, terms, cluster_centers_, num_clusters, df_tokens, xs, ys, titles, cluster_colors, cluster_names, k)
# Out:
# 532
# (5, 532)
# Top terms per cluster:
#
# Cluster 0 words:family,father,home,
#
# Cluster 0 titles: The Godfather, The Shawshank Redemption, Gone with the Wind, The Wizard of Oz, Titanic, The Godfather: Part II, Forrest Gump, The Sound of Music, E.T. the Extra-Terrestrial, Chinatown, A Streetcar Named Desire, The Best Years of Our Lives, My Fair Lady, Ben-Hur, Doctor Zhivago, Braveheart, The Pianist, Goodfellas, The Exorcist, Rain Man, Terms of Endearment, Giant, The Grapes of Wrath, Yankee Doodle Dandy, ,
#
# Cluster 1 words:New,New,York,
#
# Cluster 1 titles: Raging Bull, Singin' in the Rain, Amadeus, The Good, the Bad and the Ugly, The Apartment, High Noon, The French Connection, It Happened One Night, Midnight Cowboy, Annie Hall, Nashville, Taxi Driver,
#
# Cluster 2 words:killed,soldiers,Army,
#
# Cluster 2 titles: Schindler's List, Casablanca, One Flew Over the Cuckoo's Nest, Lawrence of Arabia, Star Wars, 2001: A Space Odyssey, The Silence of the Lambs, The Bridge on the River Kwai, Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb, Apocalypse Now, The Lord of the Rings: The Return of the King, Gladiator, From Here to Eternity, Saving Private Ryan, Unforgiven, Raiders of the Lost Ark, Patton, Jaws, Butch Cassidy and the Sundance Kid, The Treasure of the Sierra Madre, Platoon, Dances with Wolves, The Deer Hunter, All Quiet on the Western Front, Shane, Close Encounters of the Third Kind, The African Queen, Stagecoach, Mutiny on the Bounty,
#
# Cluster 3 words:Police,car,asks,
#
# Cluster 3 titles: Citizen Kane, Psycho, Sunset Blvd., Vertigo, On the Waterfront, West Side Story, Some Like It Hot, 12 Angry Men, Gandhi, Rocky, To Kill a Mockingbird, City Lights, Mr. Smith Goes to Washington, Out of Africa, Good Will Hunting, Fargo, The Green Mile, Network, The Graduate, American Graffiti, Pulp Fiction, The Maltese Falcon, A Clockwork Orange, Wuthering Heights, Double Indemnity, Rebel Without a Cause, Rear Window, The Third Man, North by Northwest,
#
# Cluster 4 words:George,marries,woman,
#
# Cluster 4 titles: It's a Wonderful Life, The Philadelphia Story, An American in Paris, The King's Speech, A Place in the Sun, Tootsie,
#
# (101, 4)
#           x         y  label          title
# 0 -0.074284 -0.132871      0  The Godfather

# %% [markdown]
# ## latent dirichlet allocation

# %%
clusters = list(map(lambda x: sorted(x, key=lambda e: e[1], reverse=True)[0][0], lda[corpus]))

# %%
terms = list(set([e[0] for c in topics_matrix for e in c[1]]))
values = [{e[0]:e[1] for e in c[1]} for c in topics_matrix]
cluster_centers_ = np.array([[values[i].get(k,0.) for k in terms] for i in range(len(values))])

# %%
cluster_names = get_cluster_names(k, cluster_centers_, terms, df_tokens)
cluster_names
# Out:
# ['family,love,father',
#  'killed,says,office',
#  'killed,soldiers,son',
#  'killed,two,asks',
#  "go,n't,friends"]

# %%
report(df_films, clusters, terms, cluster_centers_, num_clusters, df_tokens, xs, ys, titles, cluster_colors, cluster_names, k)
# Out:
# 56
# (5, 56)
# Top terms per cluster:
#
# Cluster 0 words:family,love,father,
#
# Cluster 0 titles: The Godfather, Raging Bull, Casablanca, Gone with the Wind, Citizen Kane, The Godfather: Part II, Sunset Blvd., On the Waterfront, Forrest Gump, The Sound of Music, West Side Story, Amadeus, A Streetcar Named Desire, The Philadelphia Story, An American in Paris, My Fair Lady, Out of Africa, Good Will Hunting, Terms of Endearment, Giant, The Graduate, Stagecoach, A Clockwork Orange, Rebel Without a Cause, Rear Window, Yankee Doodle Dandy, ,
#
# Cluster 1 words:killed,says,office,
#
# Cluster 1 titles: Schindler's List, Lawrence of Arabia, The Bridge on the River Kwai, It's a Wonderful Life, 12 Angry Men, Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb, Gandhi, The Lord of the Rings: The Return of the King, To Kill a Mockingbird, Doctor Zhivago, The Apartment, High Noon, The Deer Hunter, All Quiet on the Western Front, A Place in the Sun, Annie Hall, Fargo, The Grapes of Wrath, The Green Mile, Mutiny on the Bounty, Wuthering Heights, Double Indemnity,
#
# Cluster 2 words:killed,soldiers,son,
#
# Cluster 2 titles: The Wizard of Oz, Vertigo, Gladiator, Saving Private Ryan, Raiders of the Lost Ark, Ben-Hur, Braveheart, The Treasure of the Sierra Madre, Dances with Wolves, The King's Speech, Network,
#
# Cluster 3 words:killed,two,asks,
#
# Cluster 3 titles: The Shawshank Redemption, Titanic, Psycho, Star Wars, 2001: A Space Odyssey, Chinatown, Apocalypse Now, Unforgiven, The Best Years of Our Lives, Patton, Jaws, Platoon, Goodfellas, The French Connection, City Lights, It Happened One Night, Mr. Smith Goes to Washington, Rain Man, Shane, Close Encounters of the Third Kind, The Maltese Falcon, The Third Man, North by Northwest,
#
# Cluster 4 words:go,n't,friends,
#
# Cluster 4 titles: One Flew Over the Cuckoo's Nest, E.T. the Extra-Terrestrial, The Silence of the Lambs, Singin' in the Rain, Some Like It Hot, From Here to Eternity, Rocky, The Good, the Bad and the Ugly, Butch Cassidy and the Sundance Kid, The Pianist, The Exorcist, Midnight Cowboy, Tootsie, Nashville, American Graffiti, Pulp Fiction, The African Queen, Taxi Driver,
#
# (101, 4)
#           x         y  label          title
# 0 -0.074284 -0.132871      0  The Godfather

# %% [markdown]
# ## visualizing hierarchical

# %% [raw]
# fig, ax = plt.subplots(figsize=(15, 20)) # set size
# ax = dendrogram(linkage_matrix, orientation="left", labels=titles);
#
# plt.tick_params(\
#     axis= 'x',          # changes apply to the x-axis
#     which='both',    # both major and minor ticks are affected
#     bottom='off',    # ticks along the bottom edge are off
#     top='off',         # ticks along the top edge are off
#     labelbottom='off')
#
# plt.tight_layout() #show plot with tight layout
#
# plt.savefig('ward_clusters.png', dpi=200)

# %% [raw]
# plt.close()
