# %%
import os
import re
import nltk
import jieba
import joblib
import string
import codecs
import numpy as np
import pandas as pd
import plotly.express as px
#import matplotlib as mpl
#import matplotlib.pyplot as plt

from bs4 import BeautifulSoup
from itertools import chain
from functools import partial

from nltk.tag import pos_tag
from nltk.stem.snowball import SnowballStemmer

from sklearn.manifold import MDS
from sklearn.cluster import KMeans
from sklearn import feature_extraction
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

from scipy.cluster.hierarchy import ward
from scipy.cluster.hierarchy import dendrogram

from gensim import corpora
from gensim import models
from gensim import similarities

# %% [raw]
# plt.rcParams['font.sans-serif'] = ['SimHei']
# plt.rcParams['axes.unicode_minus'] = False

# %% [raw]
# %matplotlib inline

# %%
pd.set_option('display.max_rows', 10**4)

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %%
random_state = 42

# %% [markdown]
# # Data

# %% [markdown]
# ## load

# %%
path = '~/data/yk-sgz2017-chat/data-2-20201223'
# filename = '2020_09_25.csv'
# filename = '2020_09_24.csv'
filename = '2020_08_20.csv'
df = pd.read_csv(os.path.join(path, filename), index_col=0)

# %%
df.shape
# Out:
# (111636, 11)

# %%
df.head(1)
# Out:
#    gameid                                    userid        msec  serverid  \
# 0      45  Tencent_54ACA9B9A0E3B75115F82191032136D0  1597852282         1
#
#             roleid  pid rolename                                  channel  \
# 0  282303914329157   19    红軍丶柒柒  private_282303914329157_282303908677278
#
#                   content            timestamp              server
# 0  {localization:589-168}  2020-08-20 00:00:02  sgz-mix-youxi-0033

# %%
# df = df.head(1000)

# %% [markdown]
# ## tokenize

# %%
# %time texts = [jieba.lcut(text) for text in df.content]
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.681 seconds.
# Prefix dict has been built successfully.
# CPU times: user 8.66 s, sys: 184 ms, total: 8.84 s
# Wall time: 8.84 s

# %% [markdown]
# ## filter

# %%
def get_stopwords(path):
    stopwords = []
    for filename in os.listdir(path):
        with open(os.path.join(path, filename), 'r') as f:
            stopwords.extend([w.strip() for w in f.readlines()])            
    return stopwords

# %%
stopwords = get_stopwords('/home/wangyh/project/document_cluster/dicts/')
print(len(stopwords))
stopwords[:10]
# Out:
# 3885
# ['--', '?', '“', '”', '》', '－－', 'able', 'about', 'above', 'according']

# %%
# %time texts = [[word for word in text if word not in stopwords] for text in texts]
print(len(texts[0]))
# Out:
# CPU times: user 39.4 s, sys: 84 ms, total: 39.5 s
# Wall time: 39.5 s
# 4

# %%
# %time texts = [[word for word in text if 1 < len(word)] for text in texts]
print(len(texts[0]))
# Out:
# CPU times: user 212 ms, sys: 8 ms, total: 220 ms
# Wall time: 217 ms
# 3

# %% [markdown]
# ## vocab

# %%
dictionary = corpora.Dictionary(texts)
dictionary.filter_extremes(no_below=1, no_above=0.8)

# %%
corpus = [dictionary.doc2bow(text) for text in texts]
len(corpus)
# Out:
# 111636

# %% [markdown]
# # Preprocess

# %% [markdown]
# # Embedding

# %% [markdown]
# ## n-dim

# %%
tfidf_vectorizer = TfidfVectorizer(
    max_df=0.8, 
    max_features=200000,
    min_df=0.01, 
    # stop_words='english',
    use_idf=True, 
    # tokenizer=jieba.lcut, 
    ngram_range=(1,3)
)

# %%
# %time tfidf_matrix = tfidf_vectorizer.fit_transform(map(lambda t: ' '.join(t), texts))
# Out:
# CPU times: user 1.38 s, sys: 32 ms, total: 1.41 s
# Wall time: 1.41 s

# %%
print(tfidf_matrix.shape)
# Out:
# (111636, 130)

# %% [markdown]
# ## n-dim distance

# %% [raw]
# dist = 1 - cosine_similarity(tfidf_matrix)

# %% [raw]
# dist.shape

# %% [markdown]
# ## 2-dim

# %% [raw]
# MDS()
#
# # two components as we're plotting points in a two-dimensional plane
# # "precomputed" because we provide a distance matrix
# # we will also specify `random_state` so the plot is reproducible.
# mds = MDS(n_components=2, dissimilarity="precomputed", random_state=random_state, n_jobs=-1)

# %% [raw]
# # shape = (n_samples, n_components)
# %time pos = mds.fit_transform(dist)
# pos.shape

# %% [raw]
# xs, ys = pos[:, 0], pos[:, 1]

# %% [markdown]
# # Clustering

# %%
num_clusters = 10

# %% [markdown]
# ## k-means

# %%
# TODO: may be need normalize/scaling before clustering
km = KMeans(n_clusters=num_clusters, random_state=random_state)

# %%
# %time km.fit(tfidf_matrix)
# Out:
# CPU times: user 16.3 s, sys: 444 ms, total: 16.7 s
# Wall time: 2.24 s
# KMeans(n_clusters=10, random_state=42)

# %% [markdown]
# ## latent dirichlet allocation

# %% [raw]
# %time lda = models.LdaModel(corpus, \
#                             num_topics=num_clusters, \
#                             id2word=dictionary, \
#                             update_every=5, \
#                             chunksize=10000, \
#                             passes=100, \
#                             random_state=random_state)
#
# print(lda[corpus[0]])

# %% [raw]
# topics_matrix = lda.show_topics(formatted=False, num_words=20)
# topics_matrix[:1]

# %% [markdown]
# # Report

# %%
def cluster_topics(i, k, cluster_centers_, terms):
    order_centroids = cluster_centers_.argsort()[:, ::-1]
    return [terms[ind].encode().decode('utf-8', 'ignore') for ind in order_centroids[i, :k]]

# %%
def get_cluster_names(k, cluster_centers_, terms):
    return [','.join(cluster_topics(i, k, cluster_centers_, terms)) for i in range(len(cluster_centers_))]

# %%
def cluster_info(i, df, info):
    return df[df['cluster']==i][info].values.tolist()

# %%
def pprint(num_clusters, cluster_centers_, terms, df, k):

    print("Top terms per cluster:")
    print()

    for i in range(num_clusters):

        """ term import -> term vector
        """

        print("Cluster %d words:" % i, end='')
        
        for token in cluster_topics(i, k, cluster_centers_, terms):
            print(token, end=',')

        print()
        # print()

        """ cluster id -> title
        """

        print("cluster %d content:" % i)
        
        for i, title in enumerate(cluster_info(i, df, 'content')[:k]):
            # print(' %s,' % title, end='')
            print('[%s] %s' % (i, title))

        print()
        print()

# %%
def report_pprint(df, clusters, terms, cluster_centers_, num_clusters, k):
    """
    Parameter
    --------
    df : pd.DataFrame, shape=(n_samples, n_dim)
        
    clusters : list
    
    terms : vector feature name
    
    cluster_centers_ : np.array, shape=(n_clusters, n_terms)
    
    num_clusters : int
    """
    
    # add cluster info
    df['cluster'] = clusters
    print(df['cluster'].value_counts())
    
    # top tokens
    print(len(terms))
    print(cluster_centers_.shape)
    
    pprint(num_clusters, cluster_centers_, terms, df, k)

# %%
def visualizing(df_cluster):
    # df_cluster = df_cluster.astype({'label': 'int'}).astype({'label': 'str'})
    fig = px.scatter(df_cluster, x='x', y='y', color='label', hover_data=['content'])
    fig.show()

# %%
def report_visualizing(xs, ys, clusters, cluster_names, df):
    df_cluster = pd.DataFrame(dict(x=xs, y=ys, label=[cluster_names[c] for c in clusters]))
    df_cluster['content'] = df['content'].apply(lambda x: x[:5])
    
    # print(df_cluster.shape)
    # print(df_cluster.head(1))

    visualizing(df_cluster)

# %%
def report(df, clusters, terms, cluster_centers_, num_clusters, xs, ys, cluster_names, k):
    report_pprint(df, clusters, terms, cluster_centers_, num_clusters, k)
    report_visualizing(xs, ys, clusters, cluster_names, df)

# %%
k = 5

# %% [markdown]
# ## k-means

# %%
clusters = km.labels_.tolist()
cluster_centers_ = km.cluster_centers_
terms = tfidf_vectorizer.get_feature_names()
cluster_names = get_cluster_names(k, cluster_centers_, terms)
cluster_names
# Out:
# ['兄弟,battle,蜀国,游戏,有意',
#  '2222,魏国,内测 老人 带队,利用 作战 兄弟,利用 作战',
#  'localization,兄弟,功勋,繁荣,蜀国',
#  '轮子,轮子 女马,女马,轮子 女马 全家,女马 全家',
#  '1111111,作战 兄弟 加微信,兄弟 加微信,兄弟 加微信 svip12126,全家',
#  '轮子 女马 一条,女马 一条,一条,女马 一条 渣种,渣种',
#  '更好,发展 资源 更好,攻略 内测 老人,群里 攻略,更好 利用',
#  '2222222,魏国,内测 老人 带队,利用 作战 兄弟,利用 作战',
#  '资源,加微信,蜀国,功勋,魏国',
#  '高迁,功勋,私聊,吴国 高迁,吴国']

# %% [raw]
# report(df, clusters, terms, cluster_centers_, num_clusters, xs, ys, cluster_names, k)

# %%
report_pprint(df, clusters, terms, cluster_centers_, num_clusters, k)
# Out:
# 0    76802
# 2     7689
# 3     4656
# 8     4619
# 7     4454
# 9     4201
# 4     3505
# 5     2557
# 1     1633
# 6     1520
# Name: cluster, dtype: int64
# 130
# (10, 130)
# Top terms per cluster:
#
# Cluster 0 words:兄弟,battle,蜀国,游戏,有意,
# cluster 0 content:
# [0] 哈哈哈，看你这气急败坏的样子我就很舒坦
# [1] 真tm舔够 jian 人都不配做
# [2] 嘻嘻，你可保持好心态，别气的死太早呀
# [3] 还有24小时 各位施主
# [4] 御驾，早死早超生，放心的去吧
#
#
# Cluster 1 words:2222,魏国,内测 老人 带队,利用 作战 兄弟,利用 作战,
# cluster 1 content:
# [0] 2222
# [1] 2222
# [2] 2222
# [3] 2222
# [4] 2222
#
#
# Cluster 2 words:localization,兄弟,功勋,繁荣,蜀国,
# cluster 2 content:
# [0] {localization:589-168}
# [1] 施主 再偷一次？苍穹不出手那种 {localization:926-516}
# [2] 施主 单挑烽火啊 拿建业 {localization:926-516}
# [3] 亲征的那位 等你来征啊 {localization:926-516}
# [4] {localization:336-820}
#
#
# Cluster 3 words:轮子,轮子 女马,女马,轮子 女马 全家,女马 全家,
# cluster 3 content:
# [0] 二轮子死嗲又死女马，全家都是短命狗！
# [1] 二轮子死嗲又死女马，全家都是短命狗！
# [2] 二轮子死嗲又死女马，全家都是短命狗！
# [3] 二轮子死嗲又死女马，全家都是短命狗！
# [4] 二轮子死嗲又死女马，全家都是短命狗！
#
#
# Cluster 4 words:1111111,作战 兄弟 加微信,兄弟 加微信,兄弟 加微信 svip12126,全家,
# cluster 4 content:
# [0] 1111111
# [1] 1111111
# [2] 1111111
# [3] 1111111
# [4] 1111111
#
#
# Cluster 5 words:轮子 女马 一条,女马 一条,一条,女马 一条 渣种,渣种,
# cluster 5 content:
# [0] 二轮子没嗲没女马，就是一条渣种狗！
# [1] 二轮子没嗲没女马，就是一条渣种狗！
# [2] 二轮子没嗲没女马，就是一条渣种狗！
# [3] 二轮子没嗲没女马，就是一条渣种狗！
# [4] 二轮子没嗲没女马，就是一条渣种狗！
#
#
# Cluster 6 words:更好,发展 资源 更好,攻略 内测 老人,群里 攻略,更好 利用,
# cluster 6 content:
# [0] 为了军团更好的发展，资源更好的利用，大家一起作战，兄弟加微信：svip12126，领礼包，群里有攻略和内测老人带队，就差你没加了
# [1] 为了军团更好的发展，资源更好的利用，大家一起作战，兄弟加微信：svip12126，领礼包，群里有攻略和内测老人带队，就差你没加了
# [2] 为了军团更好的发展，资源更好的利用，大家一起作战，兄弟加微信：svip12126，领礼包，群里有攻略和内测老人带队，就差你没加了
# [3] 为了军团更好的发展，资源更好的利用，大家一起作战，兄弟加微信：svip12126，领礼包，群里有攻略和内测老人带队，就差你没加了
# [4] 为了军团更好的发展，资源更好的利用，大家一起作战，兄弟加微信：svip12126，领礼包，群里有攻略和内测老人带队，就差你没加了
#
#
# Cluster 7 words:2222222,魏国,内测 老人 带队,利用 作战 兄弟,利用 作战,
# cluster 7 content:
# [0] 2222222
# [1] 2222222
# [2] 2222222
# [3] 2222222
# [4] 2222222
#
#
# Cluster 8 words:资源,加微信,蜀国,功勋,魏国,
# cluster 8 content:
# [0] 大量长期出资源和功勋要的加微信18108477740。大量长期出资源和功勋要的加微信18108477740大量出资源，功勋，捐城 **等游戏一切任务，要的加微信1810847740
# [1] 大量长期出资源和功勋要的加微信18108477740。大量长期出资源和功勋要的加微信18108477740
# [2] 大量长期出资源和功勋要的加微信18108477740。大量长期出资源和功勋要的加微信18108477740大量出资源，功勋，捐城 **等游戏一切任务，要的加微信1810847740
# [3] 大量长期出资源和功勋要的加微信18108477740。大量长期出资源和功勋要的加微信18108477740
# [4] 大量长期出资源和功勋要的加微信18108477740。大量长期出资源和功勋要的加微信18108477740大量出资源，功勋，捐城 **等游戏一切任务，要的加微信1810847740
#
#
# Cluster 9 words:高迁,功勋,私聊,吴国 高迁,吴国,
# cluster 9 content:
# [0] 这个号明天进聚义，给你送高迁
# [1] 售吴国高迁号，威信tmmwgwbd
# [2] 麦高迁号带40亿资源，威信tmmwgwbd，交易猫
# [3] 售吴国高迁号，威信tmmwgwbd
# [4] 麦高迁号带40亿资源，威信tmmwgwbd，交易猫

# %% [markdown]
# ## latent dirichlet allocation

# %% [raw]
# clusters = list(map(lambda x: sorted(x, key=lambda e: e[1], reverse=True)[0][0], lda[corpus]))

# %% [raw]
# terms = list(set([e[0] for c in topics_matrix for e in c[1]]))
# values = [{e[0]:e[1] for e in c[1]} for c in topics_matrix]
# cluster_centers_ = np.array([[values[i].get(k,0.) for k in terms] for i in range(len(values))])

# %% [raw]
# cluster_names = get_cluster_names(k, cluster_centers_, terms)
# cluster_names

# %% [raw]
# report(df, clusters, terms, cluster_centers_, num_clusters, xs, ys, cluster_names, k)

# %% [markdown]
# # Data for classify

# %%
df['cluster'] = clusters

# %%
# df[df['cluster'] == 8]['content']

# %%
d = df['content'].value_counts().reset_index()

# %%
d = d.rename(columns={'content':'cnt'}).rename(columns={'index':'content'})

# %%
d[d['cnt'] > 1]['cnt'].sum() / d['cnt'].sum()
# Out:
# 0.5068347128166542

# %%
d[d['cnt'] > 1]
# Out:
#                                                 content   cnt
# 0                                               2222222  4454
# 1                                    二轮子死嗲又死女马，全家都是短命狗！  4029
# 2                                               1111111  3505
# 3                                     二轮子没嗲没女马，就是一条渣种狗！  2117
# 4                                                  2222  1632
# 5                              高价收吴国高迁号，有意的私聊，晚上九点统一回复！  1621
# 6     为了军团更好的发展，资源更好的利用，大家一起作战，兄弟加微信：svip12126，领礼包，群...  1516
# 7                                             上官海白 表字养的  1316
# 8                                            上官海白 彪子 养的  1210
# 9                                              出号，交易猫交易   855
# 10                                        代挂高迁功勋号，需要的私聊   766
# 11                                    你好，我还在线，没资源给你拉抱歉。   712
# 12    邵华不负，你ma样人，gan出大肚，邵华不负，你ma样我整出大肚，邵华不负，你ma憋不住，天...   673
# 13                    邵华不负，你ma样人，gan出大肚，邵华不负，你ma样我整出大肚，   672
# 14                                    有意请加VX18526109947   629
# 15                                      二轮子没嗲没女马，是条渣种狗！   627
# 16                                         大量回收V10以上弃坑号   623
# 17                            我是个机器人，用你一个高迁，没打到我，是不是很伤心   567
# 18                                            此时此刻正在挂机中   562
# 19                                                    好   522
# 20    130不多鱼，区内被控第一人，你是死了d，还是被玩了n，天天深更半夜清平民繁荣，你都霸服了你...   508
# 21                    本团招收蜀国有志青年，资源号，城皮号，内号共同迎接新版本，直接申请   495
# 22                                    售吴国高迁号，威信tmmwgwbd   495
# 23                            麦高迁号带40亿资源，威信tmmwgwbd，交易猫   494
# 24                                           染指招活人，蜀国加油   492
# 25                                                做人要善良   469
# 26                                        地儿隆冬强，尔隆咚锵咚咚锵   456
# 27                                    二轮子没嗲没女马，就是一条砸种狗！   440
# 28                                                    嗯   409
# 29                                           汗间团舔魏主，赞赞赞   379
# 30                                      收吴国中战号，不限v，放号私聊   368
# 31                       收魏国35加资源号,无军团 有的加VX18021856963   359
# 32                                           出售吴国高迁高等级号   348
# 33                                         收吴国资源号，卖的私聊。   345
# 34            晨曦***整个小号挨个群bb，这游戏把你玩傻，笔了吧，天天喊内，间蜀国打你还用内吗   340
# 35                晨曦你拿个比游戏当你祖宗了？现实没地位在这找**乐趣呢？你还认识***吗？   336
# 36    大量长期出资源和功勋要的加微信18108477740。大量长期出资源和功勋要的加微信1810...   336
# 37    大量长期出资源和功勋要的加微信18108477740。大量长期出资源和功勋要的加微信1810...   333
# 38                   蜀国的兄弟们，这是一场持久战，我相信胜利终将属于我们，团结一定胜利。   324
# 39                                        兄弟们，都来紫曦漂孙权啊！   322
# 40                                       欢迎所有吴国的兄弟来紫曦！！   322
# 41                                       收蜀国高迁号，私聊我中午回信   317
# 42                                                   哈哈   316
# 43                                             拾星畜生来打我呀   268
# 44                                                   好的   267
# 45                   大老黑，字黑屁股，小名**童子， 喜男人，好菊花。不好男风者请远离。   258
# 46                                大老黑，又称菊花真人，广大**群众请远离。   258
# 47    现发布“锄JIAN令”：汉JIAN唐盛世，团长魏国人富士康，团副陈胜宇，蛊惑蜀国兄弟，用蜀国...   251
# 48    现号召全面锄JIAN，每天炸汉JIAN矿5个，或清繁荣一个。欢迎所有真正热爱蜀国的兄弟一起加...   242
# 49    1佰=99万沅宝送V10+任将需要茄ⓠ ⑦Ο②⑤①②③②Ο菿咐,不封号！认准唯一ⓠ： ⑦Ο②...   241
# 50                                       大量出高迁，极速刷功勋，捐城   233
# 51                                      高价回收魏国高迁号，卖的私聊。   230
# 52                            招厨师，服务员，待遇从优，月薪5000起，有意私聊   222
# 53                               西门秃顶，您能为您后代积点德吗？不怕没py？   191
# 54                                天高的西门秃顶，您能*点阳间事说点人话吗？   190
# 55                                         欢迎新朋友加入风云再起！   168
# 56                               风云军团无论等级高低人人平等，欢迎加入我们！   167
# 57                                                    哦   164
# 58                                    大量出售资源，5元一亿，非诚勿扰。   156
# 59                        收魏国摇点途游高迁号，需要功勋的联系18251209580   143
# 60                                                    来   142
# 61                      收主公45级以上资源号，魏国跟吴国，微信15762820902   129
# 62                             出售资源10亿10元需要的加微信daliu695   127
# 63                                     我是兔子，鹰酱过来打我一梭子呀！   127
# 64                                         不要炸我矿，红手指在线！   125
# 65                    收摇点途游高迁号，出功勋有，出魏国高迁，联系18251209580   123
# 66                         收魏国，吴国55级以上资源号，微信15762820902   123
# 67            新版本报名马上截止了，还有没有吴国的散人兄弟想来飞行一起玩耍，万一分到一个低战图呢   114
# 68    喔，墨子骞 ，这个孝顺儿懆得我这个亲码嗷嗷叫 ，比至尊宝那个你野碟持久十秒 ，至尊宝现在被猪...   111
# 69                                                  私丶聊   109
# 70                                                    1   109
# 71         刚被公猪拱得爽歪歪 ，大减价 ，大甩屁了，走过路过来懆一懆 ，只要两块 ，只要两块 。    109
# 72                                                资丶源丶商   106
# 73                                                    ？   105
# 74                           高价收45级以上的弃坑号，wx18611908489   103
# 75                                                   嗯嗯   102
# 76                                                  哈哈哈   101
# 77                                 蜀二团招兵了，高战，低战，散人，都是兄弟    97
# 78                                          出本号，15远，xx猫    95
# 79                         收55级以上资源号，蜀国优先，微信15762820902    94
# 80                                                  。。。    85
# 81                                                   来了    82
# 82                                祝178、177兄弟们来*可期，平安顺遂。    80
# 83                                                 文明游戏    80
# 84                                                   OK    78
# 85                                                 文明生活    74
# 86                                               222222    73
# 87                                                   是的    69
# 88                           出滋原。甩货。需要VXIN: 17756100852    69
# 89                      狗奴才嘴上立人设时连自己都当真了，但经不起任何考验吧，啪啪打脸    66
# 90                                                    在    66
# 91    id:专打蜀贼 wx:haoxinweixin62219102 你也是可怜，你家里死得就剩你...    63
# 92                                                  Two    62
# 93    两面三刀的小人Timeless，不知道是回云天陪所谓的“兄弟”，还是像癞皮狗一样继续留在有大...    62
# 94                                                   没有    61
# 95                               种地种地，资源资源，现实太残酷，农民们辛苦啦    61
# 96                  巫马不辞辛苦的坚持送帽子，小农民的思维还真是单纯可爱惹人疼呢，哈哈哈哈    59
# 97                                                   可以    58
# 98                                                   好了    57
# 99                                                  Toy    57
# 100                                                  好吧    57
# 101                                                   对    55
# 102                                              收吴国高迁号    50
# 103                                     178钱大狗期待与你再次相遇！    49
# 104                                                  呵呵    48
# 105                                                  在吗    48
# 106           预祝{localization:177-178}的兄弟在新版本披荆斩棘，称霸一方！    48
# 107                                                  ……    48
# 108                                                   开    47
# 109                                         醉意，九峰全服第一**    47
# 110                                       收吴国高迁号，有意者私聊我    46
# 111                                没有飞过来的继续飞过来哦，9点拍照。哈哈    45
# 112                                                  谢谢    45
# 113                                                 刷功勋    45
# 114                                                  没事    45
# 115                                                   有    44
# 116                                        醉意，九峰，宝服的傻笔王    44
# 117                                                  来吧    43
# 118                             蜀二团夜星辰招兵了，高战，低战，散人，都是兄弟    42
# 119                             要资源功勋高迁找天晴VX: kouzhanyu    41
# 120                                                   恩    40
# 121                                                  哦哦    40
# 122                                                   打    40
# 123                           低-出兹原，需要的加VX: 17756100852    40
# 124                                                哈哈哈哈    39
# 125                                                  坐标    38
# 126                                                  是啊    38
# 127                                                  **    37
# 128                                                 打完了    37
# 129   今天是本服的最后一天，今晚21点（晚上没空上线的话，可以把资源用完，然后提前飞庐江占位，这样...    35
# 130                                                  ok    35
# 131                                               alarm    35
# 132                                                  厉害    34
# 133                                    谁有此不肖子的地址私发我，谢了！    34
# 134                                                 我来了    33
# 135                                                 bom    31
# 136                                                。。。。    30
# 137                              原115区不分国籍，今晚10点长安合影拍个照    30
# 138                    龍义备战192区，打造霸服天团。13356371520加微信进群    30
# 139                                                 不知道    29
# 140                                                收弃坑号    28
# 141                                                 没兵了    28
# 142                                                 打不过    28
# 143                                                  嘿嘿    28
# 144                                               收弃坑号，    28
# 145                                                  再来    28
# 146                                                   …    28
# 147                                               收蜀国高迁    27
# 148                                                   是    27
# 149                                                   我    26
# 150                                                   行    26
# 151                                                  收工    25
# 152                           收蜀国55级以上资源号，微信15762820902    25
# 153                                                  人呢    25
# 154                                                   *    25
# 155                                                  没了    24
# 156                                                   没    24
# 157   三国的弟兄们，本人准备弃坑了，以前和魏国蜀国的过节，今后都消了吧，我大小号都在这，要报仇的来...    24
# 158                                                 在吗？    24
# 159                               吴国梁山泊招收各路英雄、叛贼，共同打家劫舍    24
# 160   魏国还有一品白衫那沙比银河奥特曼，你总喊你玛了比啊！没钱别比比，有能耐你充值，纳了闷，就是你...    23
# 161                                  此号甩卖，走过路过不要错过，有意私聊    23
# 162                                                  到了    23
# 163                                            喝花酒，抱**姐    23
# 164                                               甩卖大甩卖    23
# 165                              {localization:473-532}    22
# 166                                                  在不    22
# 167                        魏国还有一品白衫银河奥特曼那个沙比，你总喊你们玛了比啊！    22
# 168                                                   牛    22
# 169                                       集结拍照留念嘛 最后一期了    21
# 170                                     大家好，我就是来凑个脸熟。。。    21
# 171                                                  驻防    21
# 172                                                  打匪    21
# 173                                                  上车    21
# 174                                                   额    21
# 175                                                  收到    20
# 176                                                 ？？？    20
# 177                                                  来啊    20
# 178                                                  切磋    20
# 179                                                  位置    19
# 180                                                 换皮肤    19
# 181                          {localization:682-114}求虐求虐    19
# 182                                                  下了    19
# 183                                                  继续    19
# 184                                                我打完了    18
# 185                                                 可以了    18
# 186                                                  等下    18
# 187                                                  发车    18
# 188                                                  拜拜    18
# 189                                                  卖吗    18
# 190                                                   2    18
# 191                                                  不是    18
# 192                                                  试试    17
# 193                                                   。    17
# 194                                                  够了    17
# 195                                                 打匪了    17
# 196                                               卖吗？？？    17
# 197                                                   撤    17
# 198                                                 0.0    17
# 199                                                   晕    16
# 200                                                  。。    16
# 201                                                   进    16
# 202                                                 不打了    16
# 203                                                   3    16
# 204                                                切磋一下    15
# 205                        本娱乐团招散人，无任务随便玩，搜索聚贤阁5，立即加入吧。    15
# 206                                                  晚安    15
# 207                                                  速度    15
# 208                                                  走了    15
# 209                              {localization:683-127}    14
# 210                                                  我来    14
# 211                                                   唉    14
# 212                                                  开了    14
# 213                              {localization:657-182}    14
# 214                                                  谢了    14
# 215                         天王盖地虎，大白卖屁股。蓝色蜀汉旗，大白告他妻。。。。    14
# 216                                       江东霸下盟赶紧到长安合影。    13
# 217                                                打不过你    13
# 218                                                  我去    13
# 219                                                  开始    13
# 220                                                  在哪    13
# 221                                                 还打吗    13
# 222                                                  撤了    13
# 223                                                 好了吗    13
# 224                                                   停    13
# 225                                                  功勋    13
# 226                                                  开吧    13
# 227                                                  88    13
# 228                                                   走    13
# 229                                                   啊    13
# 230                                                  对啊    13
# 231                                                 我满了    12
# 232                                                  派将    12
# 233                                                  加速    12
# 234                                                  再见    12
# 235                                                  嘻嘻    12
# 236                                                  马上    12
# 237                                                   啥    12
# 238                                                  你开    12
# 239                              {localization:553-766}    12
# 240                                                  不用    12
# 241                                                  完了    12
# 242                                               。。。。。    12
# 243                                              征南是个二货    12
# 244                                        今天的敌人，明天的朋友。    12
# 245                                               哈哈哈哈哈    12
# 246                                                  搞定    11
# 247                                                   发    11
# 248                              {localization:592-794}    11
# 249                                                原始皮肤    11
# 250                                                 666    11
# 251                                   低价籽圆，v17659736093    11
# 252                                                  在？    11
# 253                              {localization:718-201}    11
# 254                                                   ，    11
# 255                                                  加油    11
# 256                                              。。。。。。    11
# 257                                                   哼    11
# 258                                                 收兵线    11
# 259                                                  二队    11
# 260                                                洛阳合影    11
# 261                                                  收号    10
# 262                              {localization:304-347}    10
# 263                                                  快点    10
# 264                                                  嗯，    10
# 265      有熊3号经典人物：大白py王。国士pm男，6平方米生活圈。药石**男，喜欢花钱看常青树dp。    10
# 266                                                 还有吗    10
# 267                                              卖吗？？？？    10
# 268                                                   拉    10
# 269                                                还有几次    10
# 270                       想换个50级主公高v号！战力低一点都没关系！有出的带价私聊    10
# 271                                                  满了    10
# 272                                                 完事了    10
# 273                                                   哈    10
# 274                                        兴复汉室诚邀活跃兄弟加入    10
# 275                                                 必须的    10
# 276                                                  嗯呢    10
# 277                                                 我也是    10
# 278                                                 结束了    10
# 279                                                   快    10
# 280                                                  不能    10
# 281                              有可能延迟几分钟，尽量保证每一位兄弟都在一起    10
# 282                                                  稍等    10
# 283                                                 怎么了    10
# 284                                                  长安    10
# 285                                                  不行    10
# 286                                                 别打了     9
# 287                                                  我打     9
# 288                                   0820晚6点以后繁荣城自由开放！     9
# 289                                         江湖恩怨，一笑泯恩仇。     9
# 290                              {localization:300-337}     9
# 291                                                  飞了     9
# 292                                                  算了     9
# 293   大家好，我是圈圈，也是粉猪，亦是米啵，三国志已经相处三年了，不管恨我的，爱我的，本汉帝在这里...     9
# 294                                                没位置了     9
# 295                                                好了吗？     9
# 296                                                  随便     9
# 297                                                加入我们     9
# 298                                                  没兵     9
# 299                                                 睡觉了     9
# 300                                                  哪里     9
# 301                                                 等一下     9
# 302                                                 谢谢！     9
# 303                                                 厉害了     9
# 304                                                 不客气     9
# 305                             明天中午十二点准时上线，准备抢新版本的城池首站     9
# 306                                               骑兵连进攻     9
# 307   今天晚上集合留影咯，全体兄弟都来时间为晚上九点，地点北海郡城，统一围城。皮肤上南瓜皮肤，没有...     9
# 308                                                  快来     9
# 309                                                 没对齐     9
# 310                                                  合影     9
# 311                                                  好嘞     9
# 312                                                  打吧     9
# 313                                                还打吗？     9
# 314                                                还有一次     9
# 315                                                最后一个     9
# 316                              {localization:304-355}     9
# 317                    一白＝九百万元宝送v10加任意红将要的，加v：戴宏是癞蛤蟆（v）     9
# 318                                                  ？？     9
# 319                                                 没了吧     9
# 320                                                没次数了     8
# 321              蜀国洪荒狂战招人，不限等级，不限战力，没加军团的兄弟，加入我们，大家一起玩！     8
# 322                                                   羊     8
# 323                                                  这里     8
# 324                                                  睡觉     8
# 325                                                 知道了     8
# 326                                                   你     8
# 327                                             我们互刷功勋吧     8
# 328                              {localization:332-923}     8
# 329                                       素和元成军团，诚信招人种田     8
# 330                                           窝囊废没出息哈哈哈     8
# 331                              {localization:982-648}     8
# 332                                                  肥羊     8
# 333                                 想换个50级以上主公，换个高v号，私聊     8
# 334                                                  去吧     8
# 335                                                 谢谢了     8
# 336                                                  不要     8
# 337                                                顶战清人     8
# 338                                                有缘再见     8
# 339                                                 没有了     8
# 340                                                  等等     8
# 341                                                 在不在     8
# 342                                                  撤吧     8
# 343                                                  咋了     8
# 344                              {localization:778-242}     8
# 345                                                  收兵     8
# 346                                                 点错了     8
# 347                                                   ?     8
# 348                                                最后一次     8
# 349                                                   哎     8
# 350                                                 888     8
# 351                          大秦、南弦绿，贝戋 犭句，炸的爽吗？犭句 娘养的货。     8
# 352                                                  卧槽     8
# 353                               {localization:98-155}     8
# 354                              {localization:298-345}     8
# 355                                                  等会     8
# 356                                                  过来     8
# 357                                                 哦哦哦     7
# 358                         本娱乐团招散人，无任务随便玩，搜索聚贤阁5，立即申请！     7
# 359                                                还有人吗     7
# 360                                                  没人     7
# 361                                                位置错了     7
# 362                              {localization:298-335}     7
# 363                                                什么情况     7
# 364                                               明天更新了     7
# 365                                                  打哪     7
# 366                           没有参加10亿资源捐城的兄弟，需要你现在暂时离团。     7
# 367                                                  也是     7
# 368                                                  我开     7
# 369                                                  什么     7
# 370                                                打不过了     7
# 371                                                 我到了     7
# 372                                                 你驻防     7
# 373                                                  茄子     7
# 374                                                  开车     7
# 375                              {localization:764-788}     7
# 376                                 出资源，功勋，需要的+v:ytlzyi     7
# 377                                                 来晚了     7
# 378                                                  拉吧     7
# 379                                           收各国号，有意私聊     7
# 380                                                 打不动     7
# 381                                                 你在哪     7
# 382                                                   5     7
# 383                                                  集合     7
# 384                                                   噢     7
# 385                                                   刷     7
# 386                               {localization:42-745}     7
# 387                                                我喝酒了     7
# 388                                                   6     7
# 389                                                 没有啊     7
# 390                                                什么意思     7
# 391                                                  明白     7
# 392                              {localization:302-349}     7
# 393                                                 挂免了     7
# 394                                          收号，收资源，收高迁     7
# 395                                                  来呀     7
# 396                                                 驻防了     7
# 397                                                  怂包     7
# 398                                                  换了     7
# 399                              {localization:922-840}     7
# 400                                                   呸     7
# 401                                                你没喝酒     7
# 402                                                不好意思     7
# 403                                                 我好了     7
# 404                                                 我来开     7
# 405                                                打完了？     7
# 406                                                 来试试     7
# 407                                                  喝了     7
# 408                                                 ***     7
# 409                                                打完收工     7
# 410                                              123加油！     7
# 411                                                  在么     7
# 412                                                  我在     7
# 413                                                 哈哈，     7
# 414                              {localization:513-625}     7
# 415                                                  牛皮     6
# 416                                                  感谢     6
# 417                                                初心不改     6
# 418                                                  长沙     6
# 419                                                  兄弟     6
# 420                              {localization:457-353}     6
# 421                                                 刚上线     6
# 422                                                啦啦啦啦     6
# 423                                                  别打     6
# 424                                                 挂机了     6
# 425                                                  不打     6
# 426                                                  嗯      6
# 427           100W战以下，刷功勋：{localization:893-432}，有120W兵     6
# 428   三国弟兄们，本人准备弃坑，以前和魏蜀的过节，今后都消了吧，我大小号都在这，要报仇的来，拍完照...     6
# 429                                                  拍照     6
# 430                                                 100     6
# 431                                                  在的     6
# 432                              {localization:302-351}     6
# 433                                                  啥？     6
# 434                             大家把该领的，该换的，都弄了，别更新版本，没了     6
# 435                                                还有吗？     6
# 436                                                 ………     6
# 437                                                 我有酒     6
# 438                                                在不在？     6
# 439                                                  有啊     6
# 440                                                   号     6
# 441                              {localization:797-908}     6
# 442                                                  哦，     6
# 443                                                  在啊     6
# 444                                                  2次     6
# 445                                                 来一波     6
# 446                               {localization:77-613}     6
# 447                                                  还没     6
# 448                                                再来一次     6
# 449                                                 拍完了     6
# 450                                                 呵呵呵     6
# 451                              {localization:837-449}     6
# 452                                                 啥意思     6
# 453                              {localization:294-593}     6
# 454                                                   4     6
# 455                                                 客气了     6
# 456                              {localization:797-171}     6
# 457                                               还有几次？     6
# 458                                                ？？？？     6
# 459                                                  别了     6
# 460                                                  在来     6
# 461                                                 慢慢来     6
# 462                                                8888     6
# 463                                                  10     6
# 464                                                  一队     6
# 465                                                 打匪吗     6
# 466   今晚8点，联盟在成都拍照，成都西南门方向，已放军旗处下位，现在可去 {localizatio...     6
# 467                                      燕子坞军团成员，全体长安集合     6
# 468                                                 怎么样     6
# 469                                                  一样     6
# 470                                      九点十五分开始录屏，注意时间     6
# 471                                                还有一个     6
# 472                                            一梦坑货，坑徒弟     6
# 473                                                 是的。     6
# 474                                                 不稳定     6
# 475                                                ****     6
# 476                                                江湖再见     6
# 477                                                  报了     6
# 478                                                  打了     6
# 479                                                   卖     6
# 480                              {localization:106-656}     6
# 481   明晚0820长安城本区所有**留影，希望大家都来。有照片提供。具体地址到时发世界**，祝大家...     6
# 482                                                怎么了？     6
# 483                                               最后一个了     6
# 484                                                 开始了     6
# 485                                                  打飞     6
# 486                              {localization:354-944}     6
# 487                                             还有人打匪吗？     6
# 488                                                  打他     6
# 489                                               我也打完了     5
# 490                                                  对头     5
# 491                                                  完事     5
# 492                                                不知道啊     5
# 493                                                   谁     5
# 494                                                 来一把     5
# 495                                                结束了吗     5
# 496                                               切磋切磋。     5
# 497                                                 不清楚     5
# 498                                                 你厉害     5
# 499                                                 打不到     5
# 500                              {localization:400-540}     5
# 501                                                 我看看     5
# 502                                                谢谢兄弟     5
# 503                                                  多谢     5
# 504                                            。。。。。。。。     5
# 505                                              wanjia     5
# 506                                                 不是吧     5
# 507                                               我没次数了     5
# 508                              {localization:147-824}     5
# 509                                                 不用了     5
# 510                                                  出发     5
# 511                                                 不认识     5
# 512                                                 嘿嘿嘿     5
# 513                              {localization:641-931}     5
# 514                                                最后一下     5
# 515                                                  好滴     5
# 516                              {localization:554-547}     5
# 517                                                打匪吗？     5
# 518   各位，今天是赛季服前的最后一天，感谢大家一路坚持。现军团准备做个集体合影，地点在涪陵郡。请大...     5
# 519                            你好 麦号吗？有意请加微信18526109947     5
# 520                              {localization:122-694}     5
# 521                                              有人打匪吗？     5
# 522                                                啥意思？     5
# 523                                                  抱歉     5
# 524                              {localization:290-350}     5
# 525                                                  11     5
# 526                                                 继续啊     5
# 527                              {localization:658-924}     5
# 528                                                 我试试     5
# 529                              {localization:422-553}     5
# 530                              {localization:195-954}     5
# 531                                                 没打到     5
# 532                              {localization:615-422}     5
# 533                                                 不来了     5
# 534                                                  不在     5
# 535                                                  睡了     5
# 536                                                  没用     5
# 537                              {localization:306-343}     5
# 538                              {localization:806-652}     5
# 539                                                  好啊     5
# 540                              {localization:886-215}     5
# 541                                                这个可以     5
# 542                                                   要     5
# 543                                               有人打匪吗     5
# 544                              {localization:306-351}     5
# 545                                                 打哪？     5
# 546                                               我还有一次     5
# 547                                                来了来了     5
# 548                                                  打啊     5
# 549                              {localization:298-351}     5
# 550                                                1111     5
# 551                                                   9     5
# 552                                                 可以的     5
# 553                                         诚意收各国号！有意私聊     5
# 554                                                 嗯嗯嗯     5
# 555                                                 可以啊     5
# 556                              {localization:661-179}     5
# 557                                                 我知道     5
# 558                                                  出号     5
# 559                                                  飞走     5
# 560                              {localization:154-658}     5
# 561                                                 886     5
# 562                                                  我擦     5
# 563                                                  不急     5
# 564                                                 弃坑了     5
# 565                                                  建业     5
# 566                 白版皮肤，初心不改称号！ {localization:311-183}     5
# 567                                                 111     5
# 568                                                  刷不     5
# 569                                              有打匪的吗？     5
# 570                                               打完了吗？     5
# 571                                                 你们开     5
# 572                                                 有羊吗     5
# 573                                                  牛批     5
# 574                                                  为啥     5
# 575                              {localization:618-415}     5
# 576                                               刷功勋吗？     5
# 577                                                  你猜     5
# 578                              {localization:226-164}     5
# 579                              {localization:629-427}     5
# 580                                               换春节皮肤     5
# 581                                                  嗯！     5
# 582                                                一股上兵     5
# 583                                                  好。     5
# 584                                                 开始吧     5
# 585                                                 再见了     5
# 586                              {localization:698-196}     5
# 587   今天晚上集合留影咯，全体兄弟都来\n时间为晚上九点，地点北海郡城，统一围城。\n\n皮肤上南...     5
# 588                                                 再试试     5
# 589                                                 这么多     5
# 590                              {localization:153-851}     5
# 591                                                  在那     5
# 592                                                  打吗     5
# 593                                          八姓家奴几把恶是几把     5
# 594                                                   上     5
# 595                                                   嗨     5
# 596                                                  开啊     5
# 597                                                 一样的     5
# 598                                                刷功勋吗     5
# 599                                             。。。。。。。     5
# 600                                                 你拉吧     5
# 601                        今晚8点，联盟在成都拍照，成都南门方向，已放军旗处下位      5
# 602                               需要功勋联系18251209580长期优惠     5
# 603                                                 打匪？     5
# 604                                               最后一次了     5
# 605                              {localization:635-764}     5
# 606                                                 不会吧     5
# 607                                                  帮忙     5
# 608                              {localization:308-333}     5
# 609                                                 我小号     5
# 610                                                 我没有     5
# 611                                                 打不了     5
# 612                                                 驻防啊     5
# 613                                                  停手     5
# 614                              {localization:160-230}     5
# 615                                                   8     5
# 616                                                   ！     5
# 617                              {localization:243-604}     4
# 618                               {localization:70-168}     4
# 619                                                  准备     4
# 620                                                  咋啦     4
# 621                                                 喝酒了     4
# 622                              {localization:917-524}     4
# 623                              {localization:304-338}     4
# 624                                                 怎么啦     4
# 625                                                  嗯呐     4
# 626                       洛阳合影，10点开始，10点半结束，改版前最后一次集体**     4
# 627                                             哈哈哈哈哈哈哈     4
# 628                                                 打不赢     4
# 629                                                 好的！     4
# 630                              {localization:118-440}     4
# 631                                                 没了？     4
# 632                                                  活的     4
# 633                                               都打完了吧     4
# 634                                                再来一把     4
# 635                                                  哦      4
# 636                                                不知道呢     4
# 637                                                 别跑啊     4
# 638                              {localization:638-394}     4
# 639                                                  有酒     4
# 640                                                 发车了     4
# 641                                                 二队来     4
# 642                               {localization:30-941}     4
# 643                                                还有两次     4
# 644                                                  散了     4
# 645                                                   噗     4
# 646                                                 摸不到     4
# 647                                {localization:9-147}     4
# 648                              {localization:639-764}     4
# 649                                                 然后呢     4
# 650                                                 速度啊     4
# 651                              {localization:298-349}     4
# 652                                                   满     4
# 653                              {localization:765-469}     4
# 654                                {localization:83-51}     4
# 655                                                  科技     4
# 656                                                 在不？     4
# 657                                                  行吧     4
# 658                                                 拍好了     4
# 659                {localization:682-114}新版本前，切磋武艺？一人一炮     4
# 660                              {localization:309-355}     4
# 661                               {localization:514-79}     4
# 662                              {localization:547-118}     4
# 663                                                  Ok     4
# 664                              {localization:318-341}     4
# 665                                                 没试过     4
# 666                              {localization:612-425}     4
# 667                                                民心任务     4
# 668                              {localization:278-187}     4
# 669                              {localization:634-414}     4
# 670                                                  你发     4
# 671                                                  谁开     4
# 672                                                  历害     4
# 673                              {localization:975-844}     4
# 674                                                  好！     4
# 675                                                  啊？     4
# 676                                                ⊙∀⊙！     4
# 677                                                在哪里？     4
# 678                                                  休息     4
# 679       {battle:284009031814042,【进攻】细腰舞 胜 猎人(地点:主城),}     4
# 680                                                 想多了     4
# 681                              {localization:776-561}     4
# 682                                                   爽     4
# 683                              {localization:226-674}     4
# 684                                                  哦了     4
# 685                                           流水线几把馆是几把     4
# 686                                                 改外观     4
# 687                             收魏国高迁号，卖的+vx18502264110     4
# 688                                               我还有三次     4
# 689                                                   喔     4
# 690                                                  解散     4
# 691                                                  咋样     4
# 692                                                  废务     4
# 693                                                  跑了     4
# 694                          刷功勋 {localization:115-653}     4
# 695                                                  拉啊     4
# 696                                                 在哪？     4
# 697                              {localization:656-176}     4
# 698                                                  走吧     4
# 699                                                  忘了     4
# 700                                                 没事，     4
# 701                                                  就是     4
# 702                                                 ...     4
# 703                                   大家把自己的坐标截图！准备退场！！     4
# 704                                                你来晚了     4
# 705                                                 啥情况     4
# 706                                                 应该是     4
# 707                                                 没事了     4
# 708                              {localization:304-343}     4
# 709                                                 切磋下     4
# 710                                                还有人没     4
# 711                                                   7     4
# 712                                                打我一炮     4
# 713                                                 OK了     4
# 714                                                嗯，好的     4
# 715                               {localization:59-805}     4
# 716                                                   哇     4
# 717                                                稍等一下     4
# 718                                                最后一炮     4
# 719                                               要合区了？     4
# 720                                              有没有打匪的     4
# 721                                                来我旁边     4
# 722                                                   奥     4
# 723                               {localization:80-822}     4
# 724                                                 要多少     4
# 725                              {localization:865-988}     4
# 726                                                速度上车     4
# 727                              {localization:856-997}     4
# 728                                                  喝酒     4
# 729                                                  好咧     4
# 730                                                 没人啊     4
# 731                                                  完工     4
# 732                                                  打城     4
# 733                                                拍了没？     4
# 734                                                 我撤了     4
# 735                                                 无所谓     4
# 736                                               拍完了吗？     4
# 737                                              哈哈哈哈哈哈     4
# 738                                                  兵书     4
# 739                                                  咳咳     4
# 740   今天晚上集合留影咯，全体兄弟都来时间为晚上九点，地点北海郡城，统一围城。皮肤上南瓜皮肤，没有...     4
# 741                              {localization:963-247}     4
# 742                              {localization:633-764}     4
# 743                              {localization:139-608}     4
# 744                                                  在了     4
# 745                                                 打城了     4
# 746                                                 还可以     4
# 747                                                  好肥     4
# 748                                                  发兵     4
# 749                                                  客气     4
# 750                                                 自己人     4
# 751   为了军团更好的发展，资源更好的利用，大家一起作战，兄弟加微信：svip12126，领礼包，群...     4
# 752                                                  哦。     4
# 753                              魏国高迁包月，需要联系18251209580     4
# 754                                                  开打     4
# 755                                                我驻防了     4
# 756                                                  漂亮     4
# 757                                                  团长     4
# 758                                                  尴尬     4
# 759                                                 打过了     4
# 760                              {localization:610-443}     4
# 761                                                  捂脸     4
# 762                                                 那算了     4
# 763                          刷功勋：{localization:893-432}     4
# 764                                                  都行     4
# 765                                                  揍他     4
# 766                               {localization:39-469}     4
# 767                                                 太远了     4
# 768                                                 差不多     4
# 769                         称号改了 {localization:315-177}     4
# 770                                                  2队     4
# 771                              {localization:380-333}     4
# 772                                               打不过你了     4
# ...
# 2721                                                打完没     2
# 2722                                               天涯上车     2
# 2723  {battle:283991873792625,【进攻】强哥哥 胜 严天瑞(地点:8级伐木场),}     2
# 2724                                                在线吗     2
# 2725                                             长安拍照留念     2
# 2726                             {localization:995-582}     2
# 2727                                                有毒吧     2
# 2728                                              石头换木头     2
# 2729                                                 欧了     2
# 2730                                             嗨起来！！！     2
# 2731                             {localization:363-496}     2
# 2732                             {localization:634-426}     2
# 2733                                                又来了     2
# 2734                                                六六六     2
# 2735                                               要帮忙吗     2
# 2736                              {localization:511-72}     2
# 2737                                                换马桶     2
# 2738                              {localization:14-970}     2
# 2739                                            打匪了，兄弟们     2
# 2740                                                 弃坑     2
# 2741                                                 菜*     2
# 2742                                           你们打完就不打了     2
# 2743                                                  活     2
# 2744      {battle:284004756202345,【协防】元文姬(协防) 负 六安赵子龙,}     2
# 2745                                                 1队     2
# 2746                             {localization:296-358}     2
# 2747                                                谢谢😜     2
# 2748                              {localization:73-409}     2
# 2749                                                就一个     2
# 2750     {battle:284000463892538,【逐匪】牧梦歆 胜 5级乱军,乱军这么伤么}     2
# 2751                                                 集火     2
# 2752       所有人，在自己坐标位置截一张图后保存补缺备用，防止我漏截，截完就可以飞走了，谢谢大家配合     2
# 2753                                                  点     2
# 2754                                          晚上火速还打匪不？     2
# 2755                          集火 {localization:320-335}     2
# 2756                                                动一下     2
# 2757                                              来宇宙这里     2
# 2758                             {localization:125-580}     2
# 2759                                                休息了     2
# 2760                                                  咋     2
# 2761                             {localization:332-257}     2
# 2762                                       怂狗骂你自己呢，哈哈哈哈     2
# 2763                                           以后没机会切磋了     2
# 2764                             {localization:622-421}     2
# 2765                                               有点尴尬     2
# 2766                                               我也举手     2
# 2767                                                 没空     2
# 2768                                               打不动啊     2
# 2769                                               还打匪吗     2
# 2770                         富矿啊 {localization:465-775}     2
# 2771                                              资源多吗？     2
# 2772                                               我帮忙打     2
# 2773                             {localization:633-765}     2
# 2774                             {localization:627-829}     2
# 2775                             {localization:202-661}     2
# 2776                                                不拉了     2
# 2777                                                这个吧     2
# 2778                                              你先解散了     2
# 2779                                             小号彻底废了     2
# 2780                                                晚安。     2
# 2781                             {localization:952-781}     2
# 2782                                                 懂了     2
# 2783                                              你来打我吧     2
# 2784                                               可以飞了     2
# 2785                                                 许昌     2
# 2786                                                伐木累     2
# 2787                                                 飞吧     2
# 2788                             {localization:505-511}     2
# 2789                                                喝酒没     2
# 2790                                              你炸矿在先     2
# 2791                                                 哪？     2
# 2792                             {localization:661-186}     2
# 2793                                                 *吧     2
# 2794                                              为什么呢？     2
# 2795                                               让开一环     2
# 2796                             {localization:717-831}     2
# 2797                                             马都在一队了     2
# 2798                                                 不知     2
# 2799                                                 报数     2
# 2800                                                新版本     2
# 2801  今晚九点准时打繁荣城邺郡，速度不要磨叽，三国志2017最后一次繁荣城\n\n九点十五准备去许...     2
# 2802                              {localization:186-95}     2
# 2803                                                800     2
# 2804                                                搞不赢     2
# 2805                             {localization:724-897}     2
# 2806                             {localization:609-132}     2
# 2807                             {localization:468-954}     2
# 2808  {battle:281612500585974,【进攻】药石僧 胜 太复杂休息了(地点:主城),}     2
# 2809                                               没兵……     2
# 2810                                               多少功勋     2
# 2811                                                活1动     2
# 2812                                       收v5以上各种高战弃坑号     2
# 2813                                                完了？     2
# 2814                                                新手服     2
# 2815                                               我看也是     2
# 2816                             {localization:639-763}     2
# 2817                                              马上更新了     2
# 2818          {battle:284004756195699,【切磋】陈浩南 胜 爱樱斯坦 ,}     2
# 2819                                              改名字了？     2
# 2820                             {localization:326-270}     2
# 2821                                               哼╯*╰     2
# 2822             {battle:283996173824844,【防守】宋 负 云中铁人,}     2
# 2823                                              全部上满兵     2
# 2824                               {localization:6-269}     2
# 2825                                        团长，把军团红利发了啊     2
# 2826                             {localization:150-831}     2
# 2827                                               有没打到     2
# 2828                                                送功勋     2
# 2829                             {localization:633-766}     2
# 2830                                              哈哈哈，好     2
# 2831                                                 真假     2
# 2832                               {localization:8-996}     2
# 2833                                                 搞起     2
# 2834                              {localization:662-71}     2
# 2835  {arenabattle:282986884010375.1.1.0.【独战沙场 进攻】北梦...     2
# 2836                                                 不多     2
# 2837  {battle:281887348451813,【进攻】(s51)老支书 负 (s19)轩辕...     2
# 2838                                                 46     2
# 2839                                                怎么刷     2
# 2840                                  哈哈哈(ಡωಡ)hiahiahia     2
# 2841                          刷功勋 {localization:631-77}     2
# 2842                              {localization:664-81}     2
# 2843                             {localization:966-510}     2
# 2844                               {localization:96-63}     2
# 2845                                                哈哈。     2
# 2846                                                这有啥     2
# 2847                                             敢不敢切磋？     2
# 2848                             {localization:678-202}     2
# 2849                             {localization:625-419}     2
# 2850                                                 拍了     2
# 2851                                             不打了，闪人     2
# 2852                             {localization:187-554}     2
# 2853                                              结束了吗？     2
# 2854  {battle:282823718585576,【切磋】老司机丿南候 胜 (S136)锦衣校...     2
# 2855                                               不用理他     2
# 2856                              {localization:855-38}     2
# 2857                  刷功勋：{localization:893-432}，有120W兵     2
# 2858                             {localization:704-180}     2
# 2859                                                你发吧     2
# 2860                              {localization:725-22}     2
# 2861                                                什么？     2
# 2862                                             都打完了吗？     2
# 2863                                               三个人了     2
# 2864                             {localization:667-136}     2
# 2865                                                换称号     2
# 2866                                                 速来     2
# 2867                              {localization:83-635}     2
# 2868                                               看到你了     2
# 2869                                                 憨比     2
# 2870                                                  再     2
# 2871                                               时间到了     2
# 2872                                                 要啥     2
# 2873                             {localization:635-756}     2
# 2874                                              我还差一次     2
# 2875                             {localization:157-401}     2
# 2876                             {localization:300-348}     2
# 2877                                                10万     2
# 2878                                             统一春节皮肤     2
# 2879                                               你用上兵     2
# 2880                                               乔上一兵     2
# 2881                                                我说呢     2
# 2882                                                 开5     2
# 2883                                               我看错了     2
# 2884                                                 不怕     2
# 2885                              {localization:678-64}     2
# 2886                              {localization:900-16}     2
# 2887                              {localization:58-619}     2
# 2888                                                 去为     2
# 2889                                               喝酒了吗     2
# 2890                                                没看到     2
# 2891                                               收兵快点     2
# 2892  {battle:281612500663223,【进攻】国士无双 胜 祗祗祗祇祗祇(地点:主...     2
# 2893                                               还有3次     2
# 2894                              {localization:522-89}     2
# 2895                                               试试二队     2
# 2896                                           兄弟怎么去长安了     2
# 2897                                               打完结束     2
# 2898                          好了 {localization:315-343}     2
# 2899                             {localization:375-291}     2
# 2900       {battle:284009031793477,【逐匪】晚风拂我情 胜 4级精英流寇,}     2
# 2901                             {localization:919-514}     2
# 2902                             {localization:567-383}     2
# 2903                          派将 {localization:552-904}     2
# 2904                             {localization:641-700}     2
# 2905                                               卡卡，进     2
# 2906                             {localization:823-576}     2
# 2907                                              大家飞走吧     2
# 2908                                               恭喜恭喜     2
# 2909                                                打几级     2
# 2910                             {localization:316-354}     2
# 2911                                                继续开     2
# 2912                             {localization:121-646}     2
# 2913                                                 go     2
# 2914                             {localization:663-176}     2
# 2915                                           我的部队正在回来     2
# 2916                             {localization:450-960}     2
# 2917                             {localization:688-978}     2
# 2918                             {localization:968-902}     2
# 2919                                                运气好     2
# 2920                                              有缘再见！     2
# 2921                                                 走开     2
# 2922                                                  😜     2
# 2923                                                 啊      2
# 2924                             {localization:302-347}     2
# 2925                             {localization:316-339}     2
# 2926                                                试一下     2
# 2927                                               只有龙舟     2
# 2928                                                那还行     2
# 2929                                                继续哈     2
# 2930                                                 谁？     2
# 2931                             {localization:221-730}     2
# 2932                                               那我下了     2
# 2933                                                你打吧     2
# 2934                                                 来咯     2
# 2935                                                  能     2
# 2936                                                吃饭去     2
# 2937                                                嘿嘿😁     2
# 2938                             {localization:603-648}     2
# 2939                             {localization:833-792}     2
# 2940                                                辛苦了     2
# 2941                                                说错了     2
# 2942                      达摩种田1号 {localization:363-496}     2
# 2943                                                  炸     2
# 2944                                               我没小号     2
# 2945                             {localization:255-365}     2
# 2946                                                 😂😂     2
# 2947           {battle:283983318005065,【防守】突八 负 一气化三清,}     2
# 2948                                               我没喝酒     2
# 2949                                                哦，好     2
# 2950                             {localization:663-182}     2
# 2951                                              不要有兵线     2
# 2952                              {localization:617-88}     2
# 2953                             {localization:814-300}     2
# 2954                                          我发了信息你就完了     2
# 2955                                                 打呀     2
# 2956                                                回来了     2
# 2957                             {localization:465-348}     2
# 2958                                                 大殿     2
# 2959                                               没金子了     2
# 2960                                                开七吧     2
# 2961                             {localization:809-707}     2
# 2962                              {localization:89-746}     2
# 2963                             {localization:865-200}     2
# 2964                             {localization:115-670}     2
# 2965                             {localization:115-653}     2
# 2966                                              还差多少？     2
# 2967                               {localization:40-37}     2
# 2968                                             大头没回家？     2
# 2969                              {localization:13-481}     2
# 2970                                              今天打匪不     2
# 2971                                              不带的弄了     2
# 2972                                             你们还有几次     2
# 2973                        这个好肥的 {localization:81-668}     2
# 2974                             {localization:743-361}     2
# 2975                                               送你功勋     2
# 2976         {battle:283987596890030,【防守】项乄霸王项羽 胜 飞人甲,}     2
# 2977                                                没啥用     2
# 2978                                               呱唧呱唧     2
